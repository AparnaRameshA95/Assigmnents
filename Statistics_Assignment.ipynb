# %% [markdown]
# <a href="https://colab.research.google.com/github/AparnaRameshA95/Assigmnents/blob/main/Statistics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.** An Institution wishes to find out their student’s ability in
# mathematics, reading and writing skills. The Institution
# wants to do an exploratory study to check the following
# information.

# %%
import pandas as pd
#Load th Dataset "Students_Performance.csv"
df = pd.read_csv('/content/Students_Performance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# **a.** Find out how many males and females participated in
# the test.

# %%
gender_counts = df['gender'].value_counts()
gender_counts
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %% [markdown]
# **b.** What do you think about the students' parental level of
# education?

# %%
parental_education_level = df['parental level of education'].value_counts()
parental_education_level
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# **c.** Who scores the most on average for math, reading and writing based on
#
# **i.** Gender

# %%
#Calculating Average scores based on gender
average_scores_by_gender = df.groupby('gender')[['math score', 'reading score', 'writing score']].mean()
average_scores_by_gender
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
import matplotlib.pyplot as plt

# %%
# To find out who scores the highest on average, plot the average scores based on gender
average_scores_by_gender.plot(kind='bar', figsize=(6,4))
plt.title('Average scores based on gender')
plt.ylabel('Average score')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **ii.** Test preparation course

# %%
#Calculating Average scores based on test preparation course
average_scores_by_prep_course = df.groupby('test preparation course')[['math score', 'reading score', 'writing score']].mean()
average_scores_by_prep_course
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
# To find out who scores the highest on average, plot the average scores based on test preparation course
average_scores_by_prep_course.plot(kind='bar', figsize=(6,4))
plt.title('Average scores based on Test preparation course')
plt.ylabel('Average score')
plt.xlabel('Test preparation cource')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **d.** What do you think about the scoring variation for math, reading and writing based on
#
# **i.** Gender

# %%
# Calculating Scoring variation based on gender
variation_by_gender = df.groupby('gender')[['math score', 'reading score', 'writing score']].std()
variation_by_gender
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
# Plotting scoring variation based on gender
variation_by_gender.plot(kind='bar', figsize=(6,4))
plt.title('Scoring variation based on gender')
plt.ylabel('Scoring variation')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **ii.** Test preparation course

# %%
#calculating scoring variation based on test preparation course
variation_by_prep_course = df.groupby('test preparation course')[['math score', 'reading score', 'writing score']].std()
variation_by_prep_course
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
# Plotting scoring variation based on test preparation couse
variation_by_prep_course.plot(kind='bar', figsize=(6,4))
plt.title('Scoring variation based on test preparation couse')
plt.ylabel('Scoring variation')
plt.xlabel('Test preparation couser')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **e.** The management needs your help to give bonus points
# to the top 25% of students based on their math score,
# so how will you help the management to achieve this.

# %%
df2 = pd.read_csv('/content/Students_Performance.csv')

# %%
# Identify the top 25% of students
top_25_percentile = df['math score'].quantile(0.75)
top_25_students = df[df['math score'] > top_25_percentile]

# Define the bonus points to be awarded
bonus_points = 10

# Create a new column 'bonus points on math' and initialize it to 0
df2['bonus points on math'] = 0
# Assign bonus points to the top 25% of students
df2.loc[df2['math score'] > top_25_percentile, 'bonus points on math'] = bonus_points
# Create a new column 'Revised math score' and initialize it to 0
df2['revised math score'] = 0
# Add bonus points to the math scores of the top 25% students
df2['revised math score'] = df2['math score'] + bonus_points
# Optionally, display modified dataframe
df2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# **Case Study on Testing of Hypothesis**
#
# **2.** A company started to invest in digital marketing as a new
# way of their product promotions. For that they collected
# data and decided to carry out a study on it.
#
# **a.** The company wishes to clarify whether there is any
# increase in sales after stepping into digital marketing.

# %%
import pandas as pd
from scipy.stats import ttest_rel

# %%
#Load th Dataset "Sales_add.csv"
df_sales = pd.read_csv('/content/Sales_add.csv')
df_sales.head()
# Out:
#      Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0  Month-1  Region - A  Manager - A                          132921
# 1  Month-2  Region - A  Manager - C                          149559
# 2  Month-3  Region - B  Manager - A                          146278
# 3  Month-4  Region - B  Manager - B                          152167
# 4  Month-5  Region - C  Manager - B                          159525
#
#    Sales_After_digital_add(in $)
# 0                         270390
# 1                         223334
# 2                         244243
# 3                         231808
# 4                         258402

# %% [markdown]
# **a.** The company wishes to clarify whether there is any
# increase in sales after stepping into digital marketing.

# %%
#H0:There is no increase in sales after starting digital marketing.
#H1:There is an increase in sales after starting digital marketing.

# Assuming 'sales_before' and 'sales_after' are columns in your dataset
sales_before = df_sales['Sales_before_digital_add(in $)']
sales_after = df_sales['Sales_After_digital_add(in $)']

#t test
t_stat , p_value = stats.ttest_rel(sales_before,sales_after,alternative='greater')

# Print the results
print(f"t-statistic: {t_stat}")
print(f"p-value: {p_value}")

# Compare p-value with significance level
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: There is a significant increase in sales after digital marketing.")
else:
    print("Fail to reject null hypothesis: There is no significant increase in sales after digital marketing.")
# Out:
# t-statistic: -12.09070525287017
# p-value: 0.9999999999683167
# Fail to reject null hypothesis: There is no significant increase in sales after digital marketing.

# %% [markdown]
# **b.** The company needs to check whether there is any
# dependency between the features “Region” and
# “Manager”

# %%
#H0:There is no dependency between Region and Manager.
#H1:There is a dependency between Region and Manager.
from scipy.stats import chi2_contingency

#Create a contingency table
contingency_table = pd.crosstab(df_sales['Region'], df_sales['Manager'])

# Perform chi-square test
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-square statistic: {chi2_stat}")
print(f"P-value: {p_value}")

# Compare p-value with significance level
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: There is a significant dependency between Region and Manager.")
else:
    print("Fail to reject null hypothesis: There is no significant dependency between Region and Manager.")
# Out:
# Chi-square statistic: 3.050566893424036
# P-value: 0.5493991051158094
# Fail to reject null hypothesis: There is no significant dependency between Region and Manager.
